# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("iris[1].csv")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
pd.isnull(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
data.species.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object>

# %%
data['sepal_length'].rank()
# Out:
# 0       37.0
# 1       19.5
# 2       10.5
# 3        7.5
# 4       27.5
#        ...
# 145    126.5
# 146    104.0
# 147    118.0
# 148     97.5
# 149     82.0
# Name: sepal_length, Length: 150, dtype: float64

# %%
data.rank(ascending=False, method='max')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           118.0         24.0         139.0        144.0    150.0
# 1           134.0         93.0         139.0        144.0    150.0
# 2           141.0         55.0         146.0        144.0    150.0
# 3           145.0         67.0         127.0        144.0    150.0
# 4           128.0         18.0         139.0        144.0    150.0
# ..            ...          ...           ...          ...      ...
# 145          28.0         93.0          34.0         14.0     50.0
# 146          51.0        139.0          46.0         34.0     50.0
# 147          35.0         93.0          34.0         29.0     50.0
# 148          55.0         36.0          30.0         14.0     50.0
# 149          70.0         93.0          42.0         46.0     50.0
#
# [150 rows x 5 columns]

# %%
data.index.is_unique
# Out:
# True

# %%
new_df = data.dropna()

print(new_df.to_string())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
data['species'],categories=pd.factorize(data['species'])

data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#pplying the LabelEncoder, the 'Species' column will be transformed into numeric labels:
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['species'].unique()
data['species'] = le.fit_transform(data['species'])
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
data['sepal_width'].hist()
# Out:
# <Axes: >

# %%
data['petal_length'].hist()
# Out:
# <Axes: >

# %%
data['sepal_length'].hist(color='pink')
data['sepal_width'].hist(color='red')
data['petal_length'].hist(color='blue')
data['petal_width'].hist(color='green')
# Out:
# <Axes: >

# %%
# scatter plot showing relation between Sepal Length and Sepal Width

species=[0,1,2]
color=['red','orange','blue']
for i in range(3):
    x = data[data['species'] == species[i]]
    plt.scatter(x['sepal_length'], x['sepal_width'], c=color[i], label=species[i])

plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
# Scatter plot for Petal Length vs Petal Width 
for i in range(3):
    x = data[data['species'] == species[i]]
    plt.scatter(x['petal_length'], x['petal_width'], c=color[i], label=species[i])

plt.xlabel("petal Length")
plt.ylabel("petal Width")
plt.legend()

# %%
# Scatter plot for Petal length vs Sepal Width 
for i in range(3):
    x = data[data['species'] == species[i]]
    plt.scatter(x['petal_length'], x['sepal_width'], c=color[i], label=species[i])

plt.xlabel("petal Length")
plt.ylabel("sepa Width")
plt.legend()

# %%
count =  data.species.value_counts()
label = data.species.unique().tolist()

# Pie Chart
plt.pie(count, labels=label,  autopct='%1.1f%%')
plt.title("Species Counts", fontsize=18)
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='species', data=data)
plt.title('Species Distribution')
plt.show()

# %%
data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal_length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal_width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
corr = data.corr()

fig, ax = plt.subplots(figsize=(7, 4))
sns.heatmap(corr, annot=True, ax=ax, cmap='RdBu')
plt.show()

# %%
X = data.drop('species',axis=1)
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=data['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Features and target variable
X = data.drop(columns='species')
y = data['species']

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
X_train, X_test, y_train, y_test
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width
#  98            5.1          2.5           3.0          1.1
#  68            6.2          2.2           4.5          1.5
#  19            5.1          3.8           1.5          0.3
#  143           6.8          3.2           5.9          2.3
#  99            5.7          2.8           4.1          1.3
#  ..            ...          ...           ...          ...
#  37            4.9          3.1           1.5          0.1
#  79            5.7          2.6           3.5          1.0
#  33            5.5          4.2           1.4          0.2
#  94            5.6          2.7           4.2          1.3
#  3             4.6          3.1           1.5          0.2
#
#  [105 rows x 4 columns],
#       sepal_length  sepal_width  petal_length  petal_width
#  107           7.3          2.9           6.3          1.8
#  63            6.1          2.9           4.7          1.4
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Training the model
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Predictions
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([2, 1, 1, 1, 2, 2, 1, 1, 0, 2, 0, 0, 2, 2, 0, 2, 1, 0, 0, 0, 1, 0,
#        1, 2, 1, 1, 1, 1, 1, 0, 1, 2, 1, 0, 2, 0, 0, 0, 0, 2, 1, 0, 1, 2,
#        1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

# Assuming you have calculated accuracy and obtained a classification report

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))

# Using target names from the loaded Iris dataset
target_names = ['setosa', 'versicolor', 'virginica']

sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.decomposition import PCA

# Reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot the PCA-transformed data
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['species'] = y

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_pca, x='PC1', y='PC2', hue='species', palette='deep')
plt.title('PCA of Iris Dataset')
plt.show()
